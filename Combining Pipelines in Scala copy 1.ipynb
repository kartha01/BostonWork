// %%
import org.apache.spark.sql.types.DoubleType
import org.apache.spark.sql.types.StringType
import org.apache.spark.sql.types.DecimalType
import org.apache.spark.sql.types.LongType
import org.apache.spark.sql.functions.regexp_replace
import org.apache.spark.sql.functions.monotonically_increasing_id
import org.apache.spark.ml.feature.PCA
import org.apache.spark.ml.linalg.Vectors
import org.apache.spark.ml.feature.VectorAssembler
import org.apache.spark.sql.functions.lit
import org.apache.spark.ml.clustering.KMeans
import org.apache.spark.sql.types.StructType
import org.apache.spark.sql.types.StructField
import org.apache.spark.ml.feature.Normalizer

// %%
def setHadoopConfig(name: String) = {
    val prefix = "fs.swift2d.service." + name
    sc.hadoopConfiguration.set(prefix + ".auth.url", "https://identity.open.softlayer.com" + "/v3/auth/tokens")
    sc.hadoopConfiguration.set(prefix + ".auth.endpoint.prefix","endpoints")
    sc.hadoopConfiguration.set(prefix + ".tenant", "a9fb4d478e3d40a8bbd54c5a2ecf25a3")
    sc.hadoopConfiguration.set(prefix + ".username", "6a4cc8251c1940179a6cccc9098a15e0")
    sc.hadoopConfiguration.set(prefix + ".password", "kDTcKA2H(3eo5.G0")
    sc.hadoopConfiguration.setInt(prefix + ".http.port", 8080)
    sc.hadoopConfiguration.set(prefix + ".region", "dallas")
    sc.hadoopConfiguration.setBoolean(prefix + ".public", false)
    
    sc.hadoopConfiguration.setBoolean("parquet.enable.summary-metadata", true)
}

val name = "keystone"
setHadoopConfig(name)

// %%
/*val caseNumbers = Array(2, 3, 4, 5, 8, 9, 10, 11, 12)*/
/*don't work:
3,4,5
IllegalArgumentException: requirement failed: Decimal precision 6 exceeds max precision 5
do work:
1,2,8,9,10,11,12
*/
/* load in the first file to append (union) to */
var cases = spark.read.option("header",false).
    option("inferSchema",true).
    option("nanValue","0").
    option("nullValue","0").
    option("positiveInf","0").
    option("negativeInf","0").
    /*schema(schema).*/
    csv("swift2d://MGH." + name + "/csv/csv_case1.csv").
    withColumn("timeId", monotonically_increasing_id.cast(LongType)).
    withColumn("patId", lit(1).cast(LongType));
cases.cache()
// Out:
// 1
// [_c0: double, _c1: double ... 576 more fields]

// %%
val caseNumbers = Array(2,8,9,10,11,12)
/*loop through the rest of the files and append them to the first one*/
for(num <- caseNumbers){
    var caseTemp = spark.read.option("header",false).
            option("inferSchema",true).
            option("nanValue","0").
            option("nullValue","0").
            option("positiveInf","0").
            option("negativeInf","0").
            /*schema(schema).*/
            csv("swift2d://MGH." + name + "/csv/csv_case"+num.toString+".csv").
            withColumn("timeId", monotonically_increasing_id.cast(LongType)).
            withColumn("patId", lit(num).cast(LongType))
    cases = cases.union(caseTemp)
}
cases = cases.repartition(200)

// %%
/* files that had Inf need to have the inf changed to 0 and made into a decimal type */
for(col <- cases.schema){
    if(col.dataType == StringType){
        cases = cases.withColumn(col.name + "temp", 
                                 regexp_replace(
                                     regexp_replace(cases(col.name),"Inf","0")
                                     ,"NaN","0").cast(DoubleType))
        cases = cases.drop(col.name).withColumnRenamed(col.name + "temp",col.name)
    }
}
/* replace NaN with 0*/
cases = cases.na.fill(0)

// %%
println(cases.count())
// Out:
// 43489

// %%
/*features are all columns exept patient id and timeid*/
val feature_cols = cases.columns.filter(x => (x != "timeId" && x != "patId"))
val assembler = new VectorAssembler().setInputCols(feature_cols).setOutputCol("features")
cases = assembler.transform(cases)

// %%
/*Normalize the features*/
val normalizer = new Normalizer().setInputCol("features").setOutputCol("normFeatures")
cases = normalizer.transform(cases)

// %%
/*pca with k = 100*/
val pcaModel = new PCA().setInputCol("normFeatures").setOutputCol("pcaFeatures").setK(100).fit(cases)

cases = pcaModel.transform(cases)
cases = cases.cache()

// %%
cases.limit(2).collect().foreach(println)
// Out:
// [2.2543,2.2802,3.2058,2.7831,2.2414,2.3961,3.1904,2.8007,2.2199,2.3412,3.0924,2.7539,1.973,2.2811,3.0617,2.9103,23.097,3.1503,3.0308,3.4753,2.9078,3.1089,3.6284,4.1932,3.0422,3.6411,254330.0,226880.0,341440.0,284210.0,109680.0,113230.0,125590.0,124770.0,53409.0,56575.0,60883.0,60030.0,12915.0,13836.0,13558.0,15694.0,62.59,56.045,118.16,97.662,49.497,53.792,87.745,83.527,47.886,54.141,82.052,77.989,42.201,45.07,73.033,81.49,230.36,149.73,464.07,249.64,74.399,79.464,128.04,125.21,72.525,80.443,116.56,114.27,60.959,59.875,98.354,111.16,0.8756,0.8617,0.8544,0.88318,0.85872,0.84645,0.80648,0.85755,0.85065,0.84798,0.79293,0.84303,0.8352,0.83428,0.768,0.83579,0.15363,0.17806,0.18379,0.15705,0.16583,0.18037,0.22301,0.17244,0.17223,0.18817,0.24149,0.18405,0.1838,0.19848,0.28407,0.2061,0.029691,0.031772,0.032978,0.026176,0.037034,0.038164,0.04558,0.036112,0.0382,0.039156,0.049234,0.043254,0.043432,0.046448,0.055345,0.046391,0.0059702,0.006583,0.0086975,0.0060033,0.0072352,0.0079132,0.01156,0.0079557,0.0078441,0.0073701,0.012031,0.0084251,0.0088437,0.0092501,0.013954,0.0083079,0.7864,0.76478,0.75076,0.82598,0.78633,0.76468,0.75061,0.82589,0.78893,0.81785,0.75061,0.82855,0.051143,0.068993,0.015767,0.078448,0.095116,0.068989,0.16274,0.12168,0.14056,0.13497,0.16274,0.12168,0.0031721,0.0069194,0.0020972,0.0059682,0.017335,0.021772,0.02324,0.013302,0.017335,0.021772,0.02324,0.02574,0.0013273,0.0022133,6.2597E-4,0.0020345,0.0050095,0.0052822,0.0071827,0.0049813,0.006068,0.0052822,0.0080763,0.0065002,0.055968,0.050789,0.067392,0.046963,0.048413,0.056466,0.039713,0.033516,0.042631,0.03064,0.056204,0.016346,0.054093,0.058687,0.068919,0.054411,0.047065,0.061705,0.048629,0.049204,0.040394,0.038161,0.063963,0.049101,0.016725,0.015376,0.019602,0.016481,0.016872,0.016988,0.016493,0.017054,0.022178,0.023055,0.022402,0.017498,0.0024671,0.0023416,0.004385,0.0026256,0.0019559,0.0021107,0.0029242,0.0018799,0.0021517,0.0025362,0.0031498,0.0020964,0.96958,0.93742,0.97441,0.95341,0.91889,0.93866,0.87437,0.90986,0.88148,0.8893,0.87437,0.86588,0.23721,0.28146,0.298,0.24726,0.23724,0.24389,0.31875,0.238,0.22704,0.22075,0.31875,0.238,0.063811,0.065122,0.069426,0.061824,0.069529,0.071124,0.07216,0.067043,0.069529,0.071124,0.07216,0.067043,0.010416,0.010692,0.015259,0.010367,0.010928,0.010843,0.015787,0.010584,0.010928,0.010843,0.015787,0.010584,6.8393,5.5739,8.4173,6.4153,5.6488,5.6646,3.7873,5.3825,5.1683,4.7029,3.5289,4.885,4.8731,4.2223,2.7521,4.1493,55.0,37.768,67.721,51.019,27.908,26.424,20.213,30.063,28.715,27.488,20.018,21.945,31.097,25.286,15.183,22.555,6.5644,7.2895,8.0728,7.7866,4.9335,5.0779,5.357,5.6105,5.2729,5.7132,5.6157,5.0427,5.6867,5.7699,5.8644,5.9224,3.3145,2.6905,2.3548,3.3637,3.3145,3.1733,2.3548,3.4856,3.4748,3.7783,2.3548,3.542,11.347,11.499,10.884,12.359,11.347,11.499,10.884,12.359,11.347,11.499,10.884,12.359,3.0418,2.9524,3.4559,2.5983,3.0418,2.9524,3.4559,2.5983,3.2654,2.9524,3.4559,2.5983,3.9235,2.6579,14.631,2.6211,1.9889,3.4754,0.93425,1.6866,1.3088,1.3023,1.2918,1.568,72.583,30.706,117.83,38.121,12.965,11.853,8.6777,17.807,16.402,13.818,12.338,8.4491,3.3617,6.3925,8.5234,4.4843,1.6399,1.864,1.8293,2.5094,2.0512,2.3113,2.3945,3.1097,16.366,11.862,46.703,11.825,9.6606,13.606,5.3727,7.4263,6.2713,6.5887,5.3727,7.1162,247.47,118.78,392.54,139.49,50.848,41.728,37.624,68.399,50.848,39.072,37.624,32.752,14.504,24.223,30.182,18.427,8.108,8.5873,8.2728,9.2466,8.108,8.5873,8.2728,9.2466,18.558,10.545,18.945,15.335,5.4096,2.4142,1.3359,5.0124,-0.83095,5.4748,6.8053,3.3034,16.059,4.6209,10.33,5.5598,1.5561,5.1211,1.5696,2.9522,4.211,4.4401,5.4095,4.8911,2.2958,2.9405,4.9664,3.0661,0.92113,2.5736,1.1869,3.8884,1.5546,5.1188,-0.27736,6.3241,13.812,13.262,10.924,4.8052,2.815,4.14,4.6531,7.193,4.8075,4.909,6.1244,4.6798,0.78893,0.81785,0.75061,0.82855,0.14056,0.18697,0.24938,0.17419,0.017335,0.021772,0.03853,0.02574,0.0067597,0.0076574,0.012122,0.0067603,0.065442,0.02323,0.02459,0.010229,0.061155,0.016279,0.049055,0.04512,0.036907,0.034897,0.02378,0 ...
// [2.1797,2.257,3.0529,2.7563,2.1483,2.2865,3.0877,2.7248,2.1396,2.2458,3.0708,2.7366,2.2061,2.3466,2.8231,2.5932,4.8338,3.0265,3.1137,3.5781,3.3369,3.5624,3.687,3.0022,2.9762,3.1401,218770.0,215070.0,277590.0,263940.0,102430.0,110420.0,121240.0,122110.0,51303.0,50066.0,55929.0,59186.0,12405.0,13456.0,14544.0,15737.0,49.67,50.592,91.23,88.625,45.616,51.183,83.77,80.145,44.7,47.668,79.57,78.61,43.145,54.076,74.747,72.903,81.438,83.124,147.95,150.79,69.13,75.748,123.85,122.05,69.283,72.793,121.17,119.96,65.059,84.69,107.99,112.93,0.86873,0.85615,0.84876,0.87905,0.85274,0.8586,0.81441,0.86061,0.85691,0.84661,0.78145,0.85403,0.82232,0.82596,0.77337,0.83161,0.1606,0.18457,0.19136,0.16286,0.17449,0.16698,0.2158,0.17136,0.17444,0.18854,0.25648,0.18426,0.20265,0.21537,0.24224,0.18826,0.031508,0.032519,0.034202,0.026841,0.037861,0.035433,0.044125,0.034509,0.036772,0.042333,0.05155,0.035645,0.051955,0.056023,0.067584,0.051769,0.0063067,0.0066792,0.0089882,0.0061517,0.0074866,0.0078506,0.011269,0.0073824,0.0071912,0.0086332,0.012553,0.0070244,0.0084979,0.0082705,0.013963,0.0081779,0.7864,0.76478,0.75076,0.82598,0.78633,0.76468,0.75061,0.82589,0.78893,0.81785,0.75061,0.82855,0.094816,0.068993,0.10383,0.083239,0.14056,0.068989,0.16274,0.11507,0.14056,0.13647,0.22268,0.12252,0.0088405,0.0069194,0.004498,0.0059682,0.017335,0.021772,0.02324,0.010125,0.017335,0.021772,0.032504,0.013302,0.0021243,0.0022133,0.0027237,0.0020345,0.0050095,0.0052822,0.0071827,0.0046185,0.0050095,0.0056982,0.010164,0.0049813,0.04947,0.050614,0.058366,0.044394,0.042515,0.053591,0.047657,0.03922,0.049044,0.0282,0.034536,0.03769,0.046683,0.057783,0.054346,0.050265,0.03762,0.057432,0.052325,0.05051,0.03846,0.037466,0.042927,0.048746,0.015158,0.015131,0.018099,0.016006,0.016295,0.016358,0.016813,0.018964,0.02292,0.020818,0.019047,0.022977,0.0021366,0.0023604,0.0039465,0.0024861,0.0018875,0.0021309,0.0027553,0.0021276,0.0025929,0.0024043,0.0023468,0.002044,0.95077,0.93742,0.93262,0.95341,0.90151,0.93866,0.88046,0.9306,0.90151,0.88382,0.82844,0.90986,0.23721,0.28146,0.298,0.24726,0.23724,0.24097,0.31875,0.238,0.22704,0.22075,0.31875,0.238,0.063811,0.065122,0.069426,0.061824,0.069529,0.071124,0.07216,0.067043,0.069529,0.071124,0.07216,0.067043,0.010416,0.010692,0.015259,0.010367,0.010928,0.010843,0.015787,0.010584,0.010928,0.010843,0.015787,0.0098555,5.9813,5.335,4.9002,5.9846,5.1034,6.0719,3.9899,5.4782,5.1203,4.6748,3.1158,4.9625,4.1376,3.8365,3.194,4.4409,37.486,36.661,40.783,47.932,26.68,28.288,21.133,36.617,30.492,23.96,16.984,34.095,18.118,15.94,11.484,17.615,5.8717,7.3575,7.9975,7.8231,5.1093,5.0656,5.349,6.3571,5.6091,5.1942,5.5777,6.6498,4.2252,4.1734,3.5935,4.0712,3.3145,2.6905,2.3548,3.3637,3.3145,3.1733,2.3548,3.4856,3.4748,3.7783,2.3548,3.542,11.347,11.499,10.884,12.359,11.347,11.499,10.884,12.359,11.347,11.499,10.884,12.359,3.0418,2.9524,3.4559,2.5983,3.0418,2.9524,3.4559,2.5983,3.2654,2.9524,3.4559,2.5983,2.1993,2.6511,1.8798,2.1711,1.155,3.3403,1.0605,1.8281,1.2647,1.248,0.56589,1.7158,27.569,30.857,47.208,36.627,12.294,11.037,8.7047,28.315,16.649,11.508,6.8256,24.338,2.2029,6.3798,8.5339,4.4851,1.5951,1.8666,1.8324,3.2222,1.9991,2.4769,2.3662,3.2113,9.9823,11.862,8.9625,10.429,6.2713,13.606,5.3727,8.0875,6.2713,6.4762,3.7203,7.4263,105.43,118.78,167.48,139.49,50.848,41.728,37.624,91.909,50.848,39.072,25.487,68.399,10.595,24.223,30.182,18.427,8.108,8.5873,8.2728,11.364,8.108,8.5873,8.2728,9.2466,2.3275,2.7317,5.4021,3.0984,3.0486,3.116,2.5931,2.0253,4.7464,1.5757,4.2754,1.8108,4.8626,1.8944,4.006,4.7452,2.0776,1.2741,3.68,3.4128,2.8449,3.5938,5.611,6.8346,1.6326,3.0645,1.459,3.8506,1.6862,7.2742,1.4077,3.3713,6.9194,6.6177,-0.28959,5.8405,3.0105,2.4437,3.3876,4.6991,1.4809,3.261,2.9384,2.0286,-0.56839,4.8695,6.1654,2.0278,0.78893,0.81785,0.76135,0.82855,0.17826,0.20999,0.23509,0.17419,0.034381,0.040923,0.063008,0.036495,0.006068,0.0056982,0.012139,0.0065002,0.047229,0.011464,0.016993,0.0043285,0.034492,0.0076068,0.010101,0.019895,0.024854,0.021356,0.006471,0.0 ...

// %%
/*saving to parquet to be labeled with t-sne coordinates*/
/*cases.write.parquet("swift2d://MGH." + name + "/tempParq/7cases.parquet")*/

// %% [markdown]
// ### 15 < k < 25
//
// k: 2
// Within Set Sum of Squared Errors = 2.9112884730548816E16
// k: 4
// Within Set Sum of Squared Errors = 1.7992007329050206E16
// k: 6
// Within Set Sum of Squared Errors = 1.4551705278862694E16
// k: 8
// Within Set Sum of Squared Errors = 1.2885932983311728E16
// k: 10
// Within Set Sum of Squared Errors = 1.11832826573762E16
// k: 12
// Within Set Sum of Squared Errors = 9.081206983606092E15
// k: 14
// Within Set Sum of Squared Errors = 8.522317069652645E15
// k: 16
// Within Set Sum of Squared Errors = 7.432428413580828E15
// k: 18
// Within Set Sum of Squared Errors = 7.576234664949629E15
// k: 20
// Within Set Sum of Squared Errors = 6.743778287620577E15
// k: 22
// Within Set Sum of Squared Errors = 6.43607511491788E15
// k: 24
// Within Set Sum of Squared Errors = 5.954476368201517E15
// k: 26
// Within Set Sum of Squared Errors = 5.743758395644838E15
// k: 28
// Within Set Sum of Squared Errors = 5.479222949405443E15
// k: 30
// Within Set Sum of Squared Errors = 5.348950188771225E15
// k: 32
// Within Set Sum of Squared Errors = 4.954711625236001E15
// k: 34
// Within Set Sum of Squared Errors = 4.835574388374279E15
// k: 36
// Within Set Sum of Squared Errors = 4.815777105637914E15
// k: 38
// Within Set Sum of Squared Errors = 4.724896615554858E15
// k: 40
// Within Set Sum of Squared Errors = 4.611871574389138E15

// %%
/*kmeans with wsse.  A good k could be between 15 and 25*/
/*for(a <- 10 to 30){
    println( "k: " + a )
    var kmeans = new KMeans().setFeaturesCol("pcaFeatures").setK(a)
    var model = kmeans.fit(cases)

    var WSSSE = model.computeCost(cases)
    println(s"Within Set Sum of Squared Errors = $WSSSE")
}*/
// Out:
// k: 10
// Within Set Sum of Squared Errors = 9.541751238917884E15
// k: 11
// Within Set Sum of Squared Errors = 9.405817615503538E15
// k: 12
// Within Set Sum of Squared Errors = 8.851807434347111E15
// k: 13
// Within Set Sum of Squared Errors = 8.802021290934255E15
// k: 14
// Within Set Sum of Squared Errors = 8.004543550440997E15
// k: 15
// Within Set Sum of Squared Errors = 8.693538279624738E15
// k: 16
// Within Set Sum of Squared Errors = 7.525560733484382E15
// k: 17
// Within Set Sum of Squared Errors = 7.402581031959187E15
// k: 18
// Within Set Sum of Squared Errors = 7.085525522699249E15
// k: 19
// Within Set Sum of Squared Errors = 6.946290508784244E15
// k: 20
// Within Set Sum of Squared Errors = 6.930587732736565E15
// k: 21
// Within Set Sum of Squared Errors = 6.649059351596769E15
// k: 22
// Within Set Sum of Squared Errors = 6.354151882042983E15
// k: 23
// Within Set Sum of Squared Errors = 6.179099280347436E15
// k: 24
// Within Set Sum of Squared Errors = 5.931319774884071E15
// k: 25
// Within Set Sum of Squared Errors = 5.633257710434543E15
// k: 26
// Within Set Sum of Squared Errors = 5.659236277762013E15
// k: 27
// Within Set Sum of Squared Errors = 5.502414378576436E15
// k: 28
// Within Set Sum of Squared Errors = 5.359056508333465E15
// k: 29
// Within Set Sum of Squared Errors = 5.288429501955676E15
// k: 30
// Within Set Sum of Squared Errors = 5.244479456947975E15

// %%
/*with 18 clusters, label all points*/
var kmeans = new KMeans().setFeaturesCol("pcaFeatures").setK(18)
var kmeansModel = kmeans.fit(cases)
cases = kmeansModel.transform(cases)

// %%
cases.where(cases("timeId") === 500).select("prediction","timeId","patId","pcaFeatures").limit(1).collect().foreach(println)
// Out:
// [13,500,1,[-0.04685002433859238,-0.7935471840317845,0.19989431722432696,-0.026035551309354452,0.5664650466672222,0.06485877813358862,0.008468982141301963,0.04293673545742587,0.005450003304402173,-0.006369962485789484,0.0023203553471608214,0.011859290628000134,-0.011182237849702818,-0.005515858544289832,-0.0031218237402375155,0.0019322493686246011,0.0027406603995360343,6.492429475409141E-4,0.003243301199501925,4.398310025842497E-5,-9.810990872155996E-4,0.0013569169519016542,2.865243300826866E-4,0.005529237196960912,-0.0024721306784581502,-9.580693655523808E-4,1.1556483005478381E-4,-4.698395211770148E-4,-0.001276741858660869,3.3375167419360564E-4,-1.9644571276423482E-4,-4.296207678401921E-4,-1.0853774722169394E-4,2.0247225703949636E-4,1.6112891660482537E-4,1.8952069068533086E-5,-2.0349702270293992E-4,8.723933697613574E-4,2.2118318724955378E-5,-7.206233565904178E-5,1.899151532771148E-4,5.951371918588293E-5,1.4388268777451005E-5,4.5621541477901785E-5,1.9049242552235702E-5,2.9315715002092683E-4,1.6879148497688014E-4,-1.2103367543930639E-4,-4.7926025446414766E-5,1.8742578936870556E-4,-4.2129284750866766E-4,1.2115039529366063E-4,9.598313804666463E-5,-8.541587328638491E-6,-8.965916251561496E-5,-6.224273449036147E-5,-4.1022654189207974E-5,-3.1651683031168286E-5,-3.773538370777148E-5,6.050363867894516E-6,7.611394485889514E-5,-2.5467802810287454E-5,3.134998742953673E-5,2.986933594540197E-5,1.4119807688012344E-5,2.9298113433060545E-5,-1.0580172936339476E-5,-4.643563156792514E-6,6.671489301058627E-5,-7.421596853791307E-5,1.560539755336206E-5,-3.79738342923473E-5,-3.298018156838179E-5,-1.1749580695115517E-5,-2.6299249979728144E-5,-5.4688955710594875E-6,-9.893060186883587E-5,4.172825461560899E-5,-2.0268997109419293E-5,2.5946179447174847E-5,-3.7400305528522744E-6,-1.241089152786153E-5,1.2900793232588865E-5,-2.9061931291274346E-6,7.21597870827009E-6,4.609782548067824E-5,-2.7959517438878563E-5,-1.1092931559208983E-5,-7.977973612016077E-6,2.6551109837729875E-5,-2.6243555381045714E-5,1.9857339060053412E-6,-2.6575537305490678E-6,1.6487764376029919E-7,9.422952853775792E-6,-1.7294329947412763E-5,-7.712405170616892E-6,-2.700493045859222E-5,2.947430238543941E-5,8.137702651851878E-6]]

// %%
cases.write.option("compression","none").parquet("swift2d://MGH." + name + "/tempParq_2/1cases_2.parquet")

// %%
cases.write.csv("swift2d://MGH." + name + "/tempParq_2/case.csv")
// Out:
// Name: java.lang.UnsupportedOperationException
// Message: CSV data source does not support struct<type:tinyint,size:int,indices:array<int>,values:array<double>> data type.
// StackTrace:   at org.apache.spark.sql.execution.datasources.csv.CSVFileFormat.org$apache$spark$sql$execution$datasources$csv$CSVFileFormat$$verifyType$1(CSVFileFormat.scala:194)
//   at org.apache.spark.sql.execution.datasources.csv.CSVFileFormat$$anonfun$verifySchema$1.apply(CSVFileFormat.scala:198)
//   at org.apache.spark.sql.execution.datasources.csv.CSVFileFormat$$anonfun$verifySchema$1.apply(CSVFileFormat.scala:198)
//   at scala.collection.Iterator$class.foreach(Iterator.scala:893)
//   at scala.collection.AbstractIterator.foreach(Iterator.scala:1336)
//   at scala.collection.IterableLike$class.foreach(IterableLike.scala:72)
//   at org.apache.spark.sql.types.StructType.foreach(StructType.scala:95)
//   at org.apache.spark.sql.execution.datasources.csv.CSVFileFormat.verifySchema(CSVFileFormat.scala:198)
//   at org.apache.spark.sql.execution.datasources.csv.CSVFileFormat.prepareWrite(CSVFileFormat.scala:88)
//   at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand$$anonfun$run$1$$anonfun$4.apply(InsertIntoHadoopFsRelationCommand.scala:121)
//   at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand$$anonfun$run$1$$anonfun$4.apply(InsertIntoHadoopFsRelationCommand.scala:121)
//   at org.apache.spark.sql.execution.datasources.BaseWriterContainer.driverSideSetup(WriterContainer.scala:105)
//   at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand$$anonfun$run$1.apply$mcV$sp(InsertIntoHadoopFsRelationCommand.scala:140)
//   at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand$$anonfun$run$1.apply(InsertIntoHadoopFsRelationCommand.scala:115)
//   at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand$$anonfun$run$1.apply(InsertIntoHadoopFsRelationCommand.scala:115)
//   at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:57)
//   at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:115)
//   at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:58)
//   at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:56)
//   at org.apache.spark.sql.execution.command.ExecutedCommandExec.doExecute(commands.scala:74)
//   at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:115)
//   at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:115)
//   at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:136)
//   at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
//   at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:133)
//   at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:114)
//   at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:86)
//   at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:86)
//   at org.apache.spark.sql.execution.datasources.DataSource.write(DataSource.scala:525)
//   at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:211)
//   at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:194)
//   at org.apache.spark.sql.DataFrameWriter.csv(DataFrameWriter.scala:573)

// %%
/*if we pce with k = 2, we can use coordinates to visualize*/
/*this is run seperately from the above code*/
val twoPcaModel = new PCA().setInputCol("pcaFeatures").setOutputCol("twoFeat").setK(2).fit(cases)
var kmeansVis = twoPcaModel.transform(cases).select("twoFeat","prediction","timeId","patId")

// %%
kmeansVis.limit(2).collect().foreach(println)
// Out:
// [[0.04157707571065332,0.7632631161788315],13,0,1]
// [[0.007653574020720221,0.7793599009085888],13,1,1]

// %%
var badData = spark.read.option("header",false).
    option("inferSchema",true).
    option("nanValue","0").
    option("nullValue","0").
    option("positiveInf","0").
    option("negativeInf","0").
    /*schema(schema).*/
    csv("swift2d://MGH." + name + "/csv/csv_case3.csv").
    withColumn("timeId", monotonically_increasing_id.cast(LongType)).
    withColumn("patId", lit(1).cast(LongType));
badData.printSchema
// Out:
// 1
// root
//  |-- _c0: double (nullable = true)
//  |-- _c1: double (nullable = true)
//  |-- _c2: double (nullable = true)
//  |-- _c3: double (nullable = true)
//  |-- _c4: double (nullable = true)
//  |-- _c5: double (nullable = true)
//  |-- _c6: double (nullable = true)
//  |-- _c7: double (nullable = true)
//  |-- _c8: double (nullable = true)
//  |-- _c9: double (nullable = true)
//  |-- _c10: double (nullable = true)
//  |-- _c11: double (nullable = true)
//  |-- _c12: double (nullable = true)
//  |-- _c13: double (nullable = true)
//  |-- _c14: double (nullable = true)
//  |-- _c15: double (nullable = true)
//  |-- _c16: double (nullable = true)
//  |-- _c17: double (nullable = true)
//  |-- _c18: double (nullable = true)
//  |-- _c19: double (nullable = true)
//  |-- _c20: double (nullable = true)
//  |-- _c21: double (nullable = true)
//  |-- _c22: double (nullable = true)
//  |-- _c23: double (nullable = true)
//  |-- _c24: double (nullable = true)
//  |-- _c25: double (nullable = true)
//  |-- _c26: double (nullable = true)
//  |-- _c27: double (nullable = true)
//  |-- _c28: double (nullable = true)
//  |-- _c29: double (nullable = true)
//  |-- _c30: double (nullable = true)
//  |-- _c31: double (nullable = true)
//  |-- _c32: decimal(5,-1) (nullable = true)
//  |-- _c33: decimal(6,0) (nullable = true)
//  |-- _c34: decimal(6,0) (nullable = true)
//  |-- _c35: decimal(5,-1) (nullable = true)
//  |-- _c36: decimal(5,0) (nullable = true)
//  |-- _c37: decimal(10,0) (nullable = true)
//  |-- _c38: decimal(10,0) (nullable = true)
//  |-- _c39: decimal(10,0) (nullable = true)
//  |-- _c40: double (nullable = true)
//  |-- _c41: double (nullable = true)
//  |-- _c42: double (nullable = true)
//  |-- _c43: double (nullable = true)
//  |-- _c44: double (nullable = true)
//  |-- _c45: double (nullable = true)
//  |-- _c46: double (nullable = true)
//  |-- _c47: double (nullable = true)
//  |-- _c48: double (nullable = true)
//  |-- _c49: double (nullable = true)
//  |-- _c50: double (nullable = true)
//  |-- _c51: double (nullable = true)
//  |-- _c52: double (nullable = true)
//  |-- _c53: double (nullable = true)
//  |-- _c54: double (nullable = true)
//  |-- _c55: double (nullable = true)
//  |-- _c56: double (nullable = true)
//  |-- _c57: double (nullable = true)
//  |-- _c58: double (nullable = true)
//  |-- _c59: double (nullable = true)
//  |-- _c60: double (nullable = true)
//  |-- _c61: double (nullable = true)
//  |-- _c62: double (nullable = true)
//  |-- _c63: double (nullable = true)
//  |-- _c64: double (nullable = true)
//  |-- _c65: double (nullable = true)
//  |-- _c66: double (nullable = true)
//  |-- _c67: double (nullable = true)
//  |-- _c68: double (nullable = true)
//  |-- _c69: double (nullable = true)
//  |-- _c70: double (nullable = true)
//  |-- _c71: double (nullable = true)
//  |-- _c72: double (nullable = true)
//  |-- _c73: double (nullable = true)
//  |-- _c74: double (nullable = true)
//  |-- _c75: double (nullable = true)
//  |-- _c76: double (nullable = true)
//  |-- _c77: double (nullable = true)
//  |-- _c78: double (nullable = true)
//  |-- _c79: double (nullable = true)
//  |-- _c80: double (nullable = true)
//  |-- _c81: double (nullable = true)
//  |-- _c82: double (nullable = true)
//  |-- _c83: double (nullable = true)
//  |-- _c84: double (nullable = true)
//  |-- _c85: double (nullable = true)
//  |-- _c86: double (nullable = true)
//  |-- _c87: double (nullable = true)
//  |-- _c88: double (nullable = true)
//  |-- _c89: double (nullable = true)
//  |-- _c90: double (nullable = true)
//  |-- _c91: double (nullable = true)
//  |-- _c92: double (nullable = true)
//  |-- _c93: double (nullable = true)
//  |-- _c94: double (nullable = true)
//  |-- _c95: double (nullable = true)
//  |-- _c96: double (nullable = true)
//  |-- _c97: double (nullable = true)
//  |-- _c98: double (nullable = true)
//  |-- _c99: double (nullable = true)
//  |-- _c100: double (nullable = true)
//  |-- _c101: double (nullable = true)
//  |-- _c102: double (nullable = true)
//  |-- _c103: double (nullable = true)
//  |-- _c104: double (nullable = true)
//  |-- _c105: double (nullable = true)
//  |-- _c106: double (nullable = true)
//  |-- _c107: double (nullable = true)
//  |-- _c108: double (nullable = true)
//  |-- _c109: double (nullable = true)
//  |-- _c110: double (nullable = true)
//  |-- _c111: double (nullable = true)
//  |-- _c112: double (nullable = true)
//  |-- _c113: double (nullable = true)
//  |-- _c114: double (nullable = true)
//  |-- _c115: double (nullable = true)
//  |-- _c116: double (nullable = true)
//  |-- _c117: double (nullable = true)
//  |-- _c118: double (nullable = true)
//  |-- _c119: double (nullable = true)
//  |-- _c120: double (nullable = true)
//  |-- _c121: double (nullable = true)
//  |-- _c122: double (nullable = true)
//  |-- _c123: double (nullable = true)
//  |-- _c124: double (nullable = true)
//  |-- _c125: double (nullable = true)
//  |-- _c126: double (nullable = true)
//  |-- _c127: double (nullable = true)
//  |-- _c128: double (nullable = true)
//  |-- _c129: double (nullable = true)
//  |-- _c130: double (nullable = true)
//  |-- _c131: double (nullable = true)
//  |-- _c132: double (nullable = true)
//  |-- _c133: double (nullable = true)
//  |-- _c134: double (nullable = true)
//  |-- _c135: double (nullable = true)
//  |-- _c136: double (nullable = true)
//  |-- _c137: double (nullable = true)
//  |-- _c138: double (nullable = true)
//  |-- _c139: double (nullable = true)
//  |-- _c140: double (nullable = true)
//  |-- _c141: double (nullable = true)
//  |-- _c142: double (nullable = true)
//  |-- _c143: double (nullable = true)
//  |-- _c144: double (nullable = true)
//  |-- _c145: double (nullable = true)
//  |-- _c146: double (nullable = true)
//  |-- _c147: double (nullable = true)
//  |-- _c148: double (nullable = true)
//  |-- _c149: double (nullable = true)
//  |-- _c150: double (nullable = true)
//  |-- _c151: double (nullable = true)
//  |-- _c152: double (nullable = true)
//  |-- _c153: double (nullable = true)
//  |-- _c154: double (nullable = true)
//  |-- _c155: double (nullable = true)
//  |-- _c156: double (nullable = true)
//  |-- _c157: double (nullable = true)
//  |-- _c158: double (nullable = true)
//  |-- _c159: double (nullable = true)
//  |-- _c160: double (nullable = true)
//  |-- _c161: double (nullable = true)
//  |-- _c162: double (nullable = true)
//  |-- _c163: double (nullable = true)
//  |-- _c164: double (nullable = true)
//  |-- _c165: double (nullable = true)
//  |-- _c166: double (nullable = true)
//  |-- _c167: double (nullable = true)
//  |-- _c168: double (nullable = true)
//  |-- _c169: double (nullable = true)
//  |-- _c170: double (nullable = true)
//  |-- _c171: double (nullable = true)
//  |-- _c172: double (nullable = true)
//  |-- _c173: double (nullable = true)
//  |-- _c174: double (nullable = true)
//  |-- _c175: double (nullable = true)
//  |-- _c176: double (nullable = true)
//  |-- _c177: double (nullable = true)
//  |-- _c178: double (nullable = true)
//  |-- _c179: double (nullable = true)
//  |-- _c180: double (nullable = true)
//  |-- _c181: double (nullable = true)
//  |-- _c182: double (nullable = true)
//  |-- _c183: double (nullable = true)
//  |-- _c184: double (nullable = true)
//  |-- _c185: double (nullable = true)
//  |-- _c186: double (nullable = true)
//  |-- _c187: double (nullable = true)
//  |-- _c188: double (nullable = true)
//  |-- _c189: double (nullable = true)
//  |-- _c190: double (nullable = true)
//  |-- _c191: double (nullable = true)
//  |-- _c192: double (nullable = true)
//  |-- _c193: double (nullable = true)
//  |-- _c194: double (nullable = true)
//  |-- _c195: double (nullable = true)
//  |-- _c196: double (nullable = true)
//  |-- _c197: double (nullable = true)
//  |-- _c198: double (nullable = true)
//  |-- _c199: double (nullable = true)
//  |-- _c200: double (nullable = true)
//  |-- _c201: double (nullable = true)
//  |-- _c202: double (nullable = true)
//  |-- _c203: double (nullable = true)
//  |-- _c204: double (nullable = true)
//  |-- _c205: double (nullable = true)
//  |-- _c206: double (nullable = true)
//  |-- _c207: double (nullable = true)
//  |-- _c208: double (nullable = true)
//  |-- _c209: double (nullable = true)
//  |-- _c210: double (nullable = true)
//  |-- _c211: double (nullable = true)
//  |-- _c212: double (nullable = true)
//  |-- _c213: double (nullable = true)
//  |-- _c214: double (nullable = true)
//  |-- _c215: double (nullable = true)
//  |-- _c216: double (nullable = true)
//  |-- _c217: double (nullable = true)
//  |-- _c218: double (nullable = true)
//  |-- _c219: double (nullable = true)
//  |-- _c220: double (nullable = true)
//  |-- _c221: double (nullable = true)
//  |-- _c222: double (nullable = true)
//  |-- _c223: double (nullable = true)
//  |-- _c224: double (nullable = true)
//  |-- _c225: double (nullable = true)
//  |-- _c226: double (nullable = true)
//  |-- _c227: double (nullable = true)
//  |-- _c228: double (nullable = true)
//  |-- _c229: double (nullable = true)
//  |-- _c230: double (nullable = true)
//  |-- _c231: double (nullable = true)
//  |-- _c232: double (nullable = true)
//  |-- _c233: double (nullable = true)
//  |-- _c234: double (nullable = true)
//  |-- _c235: double (nullable = true)
//  |-- _c236: double (nullable = true)
//  |-- _c237: double (nullable = true)
//  |-- _c238: double (nullable = true)
//  |-- _c239: double (nullable = true)
//  |-- _c240: double (nullable = true)
//  |-- _c241: double (nullable = true)
//  |-- _c242: double (nullable = true)
//  |-- _c243: double (nullable = true)
//  |-- _c244: double (nullable = true)
//  |-- _c245: double (nullable = true)
//  |-- _c246: double (nullable = true)
//  |-- _c247: double (nullable = true)
//  |-- _c248: double (nullable = true)
//  |-- _c249: double (nullable = true)
//  |-- _c250: double (nullable = true)
//  |-- _c251: double (nullable = true)
//  |-- _c252: double (nullable = true)
//  |-- _c253: double (nullable = true)
//  |-- _c254: double (nullable = true)
//  |-- _c255: double (nullable = true)
//  |-- _c256: double (nullable = true)
//  |-- _c257: double (nullable = true)
//  |-- _c258: double (nullable = true)
//  |-- _c259: double (nullable = true)
//  |-- _c260: double (nullable = true)
//  |-- _c261: double (nullable = true)
//  |-- _c262: double (nullable = true)
//  |-- _c263: double (nullable = true)
//  |-- _c264: double (nullable = true)
//  |-- _c265: double (nullable = true)
//  |-- _c266: double (nullable = true)
//  |-- _c267: double (nullable = true)
//  |-- _c268: double (nullable = true)
//  |-- _c269: double (nullable = true)
//  |-- _c270: double (nullable = true)
//  |-- _c271: double (nullable = true)
//  |-- _c272: double (nullable = true)
//  |-- _c273: double (nullable = true)
//  |-- _c274: double (nullable = true)
//  |-- _c275: double (nullable = true)
//  |-- _c276: double (nullable = true)
//  |-- _c277: double (nullable = true)
//  |-- _c278: double (nullable = true)
//  |-- _c279: double (nullable = true)
//  |-- _c280: double (nullable = true)
//  |-- _c281: double (nullable = true)
//  |-- _c282: double (nullable = true)
//  |-- _c283: double (nullable = true)
//  |-- _c284: double (nullable = true)
//  |-- _c285: double (nullable = true)
//  |-- _c286: double (nullable = true)
//  |-- _c287: double (nullable = true)
//  |-- _c288: double (nullable = true)
//  |-- _c289: double (nullable = true)
//  |-- _c290: double (nullable = true)
//  |-- _c291: double (nullable = true)
//  |-- _c292: double (nullable = true)
//  |-- _c293: double (nullable = true)
//  |-- _c294: double (nullable = true)
//  |-- _c295: double (nullable = true)
//  |-- _c296: double (nullable = true)
//  |-- _c297: double (nullable = true)
//  |-- _c298: double (nullable = true)
//  |-- _c299: double (nullable = true)
//  |-- _c300: double (nullable = true)
//  |-- _c301: double (nullable = true)
//  |-- _c302: double (nullable = true)
//  |-- _c303: double (nullable = true)
//  |-- _c304: double (nullable = true)
//  |-- _c305: double (nullable = true)
//  |-- _c306: double (nullable = true)
//  |-- _c307: double (nullable = true)
//  |-- _c308: double (nullable = true)
//  |-- _c309: double (nullable = true)
//  |-- _c310: double (nullable = true)
//  |-- _c311: double (nullable = true)
//  |-- _c312: double (nullable = true)
//  |-- _c313: double (nullable = true)
//  |-- _c314: double (nullable = true)
//  |-- _c315: double (nullable = true)
//  |-- _c316: double (nullable = true)
//  |-- _c317: double (nullable = true)
//  |-- _c318: double (nullable = true)
//  |-- _c319: double (nullable = true)
//  |-- _c320: double (nullable = true)
//  |-- _c321: double (nullable = true)
//  |-- _c322: double (nullable = true)
//  |-- _c323: double (nullable = true)
//  |-- _c324: double (nullable = true)
//  |-- _c325: double (nullable = true)
//  |-- _c326: double (nullable = true)
//  |-- _c327: double (nullable = true)
//  |-- _c328: double (nullable = true)
//  |-- _c329: double (nullable = true)
//  |-- _c330: double (nullable = true)
//  |-- _c331: double (nullable = true)
//  |-- _c332: double (nullable = true)
//  |-- _c333: double (nullable = true)
//  |-- _c334: double (nullable = true)
//  |-- _c335: double (nullable = true)
//  |-- _c336: double (nullable = true)
//  |-- _c337: double (nullable = true)
//  |-- _c338: double (nullable = true)
//  |-- _c339: double (nullable = true)
//  |-- _c340: double (nullable = true)
//  |-- _c341: double (nullable = true)
//  |-- _c342: double (nullable = true)
//  |-- _c343: double (nullable = true)
//  |-- _c344: double (nullable = true)
//  |-- _c345: double (nullable = true)
//  |-- _c346: double (nullable = true)
//  |-- _c347: double (nullable = true)
//  |-- _c348: double (nullable = true)
//  |-- _c349: double (nullable = true)
//  |-- _c350: double (nullable = true)
//  |-- _c351: double (nullable = true)
//  |-- _c352: double (nullable = true)
//  |-- _c353: double (nullable = true)
//  |-- _c354: double (nullable = true)
//  |-- _c355: double (nullable = true)
//  |-- _c356: double (nullable = true)
//  |-- _c357: double (nullable = true)
//  |-- _c358: double (nullable = true)
//  |-- _c359: double (nullable = true)
//  |-- _c360: double (nullable = true)
//  |-- _c361: double (nullable = true)
//  |-- _c362: double (nullable = true)
//  |-- _c363: double (nullable = true)
//  |-- _c364: double (nullable = true)
//  |-- _c365: double (nullable = true)
//  |-- _c366: double (nullable = true)
//  |-- _c367: double (nullable = true)
//  |-- _c368: double (nullable = true)
//  |-- _c369: double (nullable = true)
//  |-- _c370: double (nullable = true)
//  |-- _c371: double (nullable = true)
//  |-- _c372: double (nullable = true)
//  |-- _c373: double (nullable = true)
//  |-- _c374: double (nullable = true)
//  |-- _c375: double (nullable = true)
//  |-- _c376: double (nullable = true)
//  |-- _c377: double (nullable = true)
//  |-- _c378: double (nullable = true)
//  |-- _c379: double (nullable = true)
//  |-- _c380: double (nullable = true)
//  |-- _c381: double (nullable = true)
//  |-- _c382: double (nullable = true)
//  |-- _c383: double (nullable = true)
//  |-- _c384: double (nullable = true)
//  |-- _c385: double (nullable = true)
//  |-- _c386: double (nullable = true)
//  |-- _c387: double (nullable = true)
//  |-- _c388: double (nullable = true)
//  |-- _c389: double (nullable = true)
//  |-- _c390: double (nullable = true)
//  |-- _c391: double (nullable = true)
//  |-- _c392: double (nullable = true)
//  |-- _c393: double (nullable = true)
//  |-- _c394: double (nullable = true)
//  |-- _c395: double (nullable = true)
//  |-- _c396: double (nullable = true)
//  |-- _c397: double (nullable = true)
//  |-- _c398: double (nullable = true)
//  |-- _c399: double (nullable = true)
//  |-- _c400: double (nullable = true)
//  |-- _c401: double (nullable = true)
//  |-- _c402: double (nullable = true)
//  |-- _c403: double (nullable = true)
//  |-- _c404: double (nullable = true)
//  |-- _c405: double (nullable = true)
//  |-- _c406: double (nullable = true)
//  |-- _c407: double (nullable = true)
//  |-- _c408: double (nullable = true)
//  |-- _c409: double (nullable = true)
//  |-- _c410: double (nullable = true)
//  |-- _c411: double (nullable = true)
//  |-- _c412: double (nullable = true)
//  |-- _c413: double (nullable = true)
//  |-- _c414: double (nullable = true)
//  |-- _c415: double (nullable = true)
//  |-- _c416: double (nullable = true)
//  |-- _c417: double (nullable = true)
//  |-- _c418: double (nullable = true)
//  |-- _c419: double (nullable = true)
//  |-- _c420: double (nullable = true)
//  |-- _c421: double (nullable = true)
//  |-- _c422: double (nullable = true)
//  |-- _c423: double (nullable = true)
//  |-- _c424: double (nullable = true)
//  |-- _c425: double (nullable = true)
//  |-- _c426: double (nullable = true)
//  |-- _c427: double (nullable = true)
//  |-- _c428: double (nullable = true)
//  |-- _c429: double (nullable = true)
//  |-- _c430: double (nullable = true)
//  |-- _c431: double (nullable = true)
//  |-- _c432: double (nullable = true)
//  |-- _c433: double (nullable = true)
//  |-- _c434: double (nullable = true)
//  |-- _c435: double (nullable = true)
//  |-- _c436: double (nullable = true)
//  |-- _c437: double (nullable = true)
//  |-- _c438: double (nullable = true)
//  |-- _c439: double (nullable = true)
//  |-- _c440: double (nullable = true)
//  |-- _c441: double (nullable = true)
//  |-- _c442: double (nullable = true)
//  |-- _c443: double (nullable = true)
//  |-- _c444: double (nullable = true)
//  |-- _c445: double (nullable = true)
//  |-- _c446: double (nullable = true)
//  |-- _c447: double (nullable = true)
//  |-- _c448: double (nullable = true)
//  |-- _c449: double (nullable = true)
//  |-- _c450: double (nullable = true)
//  |-- _c451: double (nullable = true)
//  |-- _c452: double (nullable = true)
//  |-- _c453: double (nullable = true)
//  |-- _c454: double (nullable = true)
//  |-- _c455: double (nullable = true)
//  |-- _c456: double (nullable = true)
//  |-- _c457: double (nullable = true)
//  |-- _c458: double (nullable = true)
//  |-- _c459: double (nullable = true)
//  |-- _c460: double (nullable = true)
//  |-- _c461: double (nullable = true)
//  |-- _c462: double (nullable = true)
//  |-- _c463: double (nullable = true)
//  |-- _c464: double (nullable = true)
//  |-- _c465: double (nullable = true)
//  |-- _c466: double (nullable = true)
//  |-- _c467: double (nullable = true)
//  |-- _c468: double (nullable = true)
//  |-- _c469: double (nullable = true)
//  |-- _c470: double (nullable = true)
//  |-- _c471: double (nullable = true)
//  |-- _c472: double (nullable = true)
//  |-- _c473: double (nullable = true)
//  |-- _c474: double (nullable = true)
//  |-- _c475: double (nullable = true)
//  |-- _c476: double (nullable = true)
//  |-- _c477: double (nullable = true)
//  |-- _c478: double (nullable = true)
//  |-- _c479: double (nullable = true)
//  |-- _c480: double (nullable = true)
//  |-- _c481: double (nullable = true)
//  |-- _c482: double (nullable = true)
//  |-- _c483: double (nullable = true)
//  |-- _c484: double (nullable = true)
//  |-- _c485: double (nullable = true)
//  |-- _c486: double (nullable = true)
//  |-- _c487: double (nullable = true)
//  |-- _c488: double (nullable = true)
//  |-- _c489: double (nullable = true)
//  |-- _c490: double (nullable = true)
//  |-- _c491: double (nullable = true)
//  |-- _c492: double (nullable = true)
//  |-- _c493: double (nullable = true)
//  |-- _c494: double (nullable = true)
//  |-- _c495: double (nullable = true)
//  |-- _c496: double (nullable = true)
//  |-- _c497: double (nullable = true)
//  |-- _c498: double (nullable = true)
//  |-- _c499: double (nullable = true)
//  |-- _c500: double (nullable = true)
//  |-- _c501: double (nullable = true)
//  |-- _c502: double (nullable = true)
//  |-- _c503: double (nullable = true)
//  |-- _c504: double (nullable = true)
//  |-- _c505: double (nullable = true)
//  |-- _c506: double (nullable = true)
//  |-- _c507: double (nullable = true)
//  |-- _c508: double (nullable = true)
//  |-- _c509: double (nullable = true)
//  |-- _c510: double (nullable = true)
//  |-- _c511: double (nullable = true)
//  |-- _c512: double (nullable = true)
//  |-- _c513: double (nullable = true)
//  |-- _c514: double (nullable = true)
//  |-- _c515: double (nullable = true)
//  |-- _c516: double (nullable = true)
//  |-- _c517: double (nullable = true)
//  |-- _c518: double (nullable = true)
//  |-- _c519: double (nullable = true)
//  |-- _c520: double (nullable = true)
//  |-- _c521: double (nullable = true)
//  |-- _c522: double (nullable = true)
//  |-- _c523: double (nullable = true)
//  |-- _c524: double (nullable = true)
//  |-- _c525: double (nullable = true)
//  |-- _c526: double (nullable = true)
//  |-- _c527: double (nullable = true)
//  |-- _c528: double (nullable = true)
//  |-- _c529: double (nullable = true)
//  |-- _c530: double (nullable = true)
//  |-- _c531: double (nullable = true)
//  |-- _c532: double (nullable = true)
//  |-- _c533: double (nullable = true)
//  |-- _c534: double (nullable = true)
//  |-- _c535: double (nullable = true)
//  |-- _c536: double (nullable = true)
//  |-- _c537: double (nullable = true)
//  |-- _c538: double (nullable = true)
//  |-- _c539: double (nullable = true)
//  |-- _c540: double (nullable = true)
//  |-- _c541: double (nullable = true)
//  |-- _c542: double (nullable = true)
//  |-- _c543: double (nullable = true)
//  |-- _c544: double (nullable = true)
//  |-- _c545: double (nullable = true)
//  |-- _c546: double (nullable = true)
//  |-- _c547: double (nullable = true)
//  |-- _c548: double (nullable = true)
//  |-- _c549: double (nullable = true)
//  |-- _c550: double (nullable = true)
//  |-- _c551: double (nullable = true)
//  |-- _c552: double (nullable = true)
//  |-- _c553: double (nullable = true)
//  |-- _c554: double (nullable = true)
//  |-- _c555: double (nullable = true)
//  |-- _c556: double (nullable = true)
//  |-- _c557: double (nullable = true)
//  |-- _c558: double (nullable = true)
//  |-- _c559: double (nullable = true)
//  |-- _c560: double (nullable = true)
//  |-- _c561: double (nullable = true)
//  |-- _c562: double (nullable = true)
//  |-- _c563: double (nullable = true)
//  |-- _c564: double (nullable = true)
//  |-- _c565: double (nullable = true)
//  |-- _c566: double (nullable = true)
//  |-- _c567: double (nullable = true)
//  |-- _c568: double (nullable = true)
//  |-- _c569: double (nullable = true)
//  |-- _c570: double (nullable = true)
//  |-- _c571: double (nullable = true)
//  |-- _c572: double (nullable = true)
//  |-- _c573: double (nullable = true)
//  |-- _c574: double (nullable = true)
//  |-- _c575: double (nullable = true)
//  |-- timeId: long (nullable = false)
//  |-- patId: long (nullable = false)

// %%
/*create schema*/
import scala.collection.mutable.ArrayBuffer
var fields = ArrayBuffer[StructField]()
for(num <- 0 to 575){
    fields += StructField("_c" + num.toString,DecimalType(10,0))
}
var schema = StructType(fields)
schema.fields
// Out:
// Array(StructField(_c0,DecimalType(10,0),true), StructField(_c1,DecimalType(10,0),true), StructField(_c2,DecimalType(10,0),true), StructField(_c3,DecimalType(10,0),true), StructField(_c4,DecimalType(10,0),true), StructField(_c5,DecimalType(10,0),true), StructField(_c6,DecimalType(10,0),true), StructField(_c7,DecimalType(10,0),true), StructField(_c8,DecimalType(10,0),true), StructField(_c9,DecimalType(10,0),true), StructField(_c10,DecimalType(10,0),true), StructField(_c11,DecimalType(10,0),true), StructField(_c12,DecimalType(10,0),true), StructField(_c13,DecimalType(10,0),true), StructField(_c14,DecimalType(10,0),true), StructField(_c15,DecimalType(10,0),true), StructField(_c16,DecimalType(10,0),true), StructField(_c17,DecimalType(10,...

// %%
/* all double columns need to be made to decimal*/
import java.util.Calendar
println(Calendar.getInstance().getTime())
println(now)
for(col <- cases.schema){
    println(col.name)
    if(col.dataType == DoubleType){
        cases = cases.withColumn(col.name + "temp", cases(col.name).cast(DecimalType(10,0))).drop(col.name).withColumnRenamed(col.name + "temp",col.name)
    }
}
println(Calendar.getInstance().getTime())
// Out:
// Wed May 31 21:05:43 CDT 2017
// Wed May 31 21:04:38 CDT 2017
// _c0
// _c1
// _c2
// _c3
// _c4
// _c5
// _c6
// _c7
// _c8
// _c9
// _c10
// _c11
// _c12
// _c13
// _c14
// _c15
// _c30
// _c31
// _c32
// _c33
// _c34
// _c35
// _c36
// _c37
// _c38
// _c39
// _c40
// _c41
// _c42
// _c43
// _c44
// _c45
// _c46
// _c47
// _c48
// _c49
// _c50
// _c51
// _c52
// _c53
// _c54
// _c55
// _c56
// _c57
// _c58
// _c59
// _c60
// _c61
// _c62
// _c63
// _c64
// _c65
// _c66
// _c67
// _c68
// _c69
// _c70
// _c71
// _c72
// _c73
// _c74
// _c75
// _c76
// _c77
// _c78
// _c79
// _c80
// _c81
// _c82
// _c83
// _c84
// _c85
// _c86
// _c87
// _c88
// _c89
// _c90
// _c91
// _c92
// _c93
// _c94
// _c95
// _c96
// _c97
// _c98
// _c99
// _c100
// _c101
// _c102
// _c103
// _c104
// _c105
// _c106
// _c107
// _c108
// _c109
// _c110
// _c111
// _c112
// _c113
// _c114
// _c115
// _c116
// _c117
// _c118
// _c119
// _c120
// _c121
// _c122
// _c123
// _c124
// _c125
// _c126
// _c127
// _c128
// _c129
// _c130
// _c131
// _c132
// _c133
// _c134
// _c135
// _c136
// _c137
// _c138
// _c139
// _c140
// _c141
// _c142
// _c143
// _c144
// _c145
// _c146
// _c147
// _c148
// _c149
// _c150
// _c151
// _c152
// _c153
// _c154
// _c155
// _c156
// _c157
// _c158
// _c159
// _c160
// _c161
// _c162
// _c163
// _c164
// _c165
// _c166
// _c167
// _c168
// _c169
// _c170
// _c171
// _c172
// _c173
// _c174
// _c175
// _c176
// _c177
// _c178
// _c179
// _c180
// _c181
// _c182
// _c183
// _c184
// _c185
// _c186
// _c187
// _c188
// _c189
// _c190
// _c191
// _c192
// _c193
// _c194
// _c195
// _c196
// _c197
// _c198
// _c199
// _c200
// _c201
// _c202
// _c203
// _c204
// _c205
// _c206
// _c207
// _c208
// _c209
// _c210
// _c211
// _c212
// _c213
// _c214
// _c215
// _c216
// _c217
// _c218
// _c219
// _c220
// _c221
// _c222
// _c223
// _c224
// _c225
// _c226
// _c227
// _c228
// _c229
// _c230
// _c231
// _c232
// _c233
// _c234
// _c235
// _c236
// _c237
// _c238
// _c239
// _c240
// _c241
// _c242
// _c243
// _c244
// _c245
// _c246
// _c247
// _c248
// _c249
// _c250
// _c251
// _c252
// _c253
// _c254
// _c255
// _c256
// _c257
// _c258
// _c259
// _c260
// _c261
// _c262
// _c263
// _c264
// _c265
// _c266
// _c267
// _c268
// _c269
// _c270
// _c271
// _c272
// _c273
// _c274
// _c275
// _c276
// _c277
// _c278
// _c279
// _c280
// _c281
// _c282
// _c283
// _c284
// _c285
// _c286
// _c287
// _c288
// _c289
// _c290
// _c291
// _c292
// _c293
// _c294
// _c295
// _c296
// _c297
// _c298
// _c299
// _c300
// _c301
// _c302
// _c303
// _c304
// _c305
// _c306
// _c307
// _c308
// _c309
// _c310
// _c311
// _c312
// _c313
// _c314
// _c315
// _c316
// _c317
// _c318
// _c319
// _c320
// _c321
// _c322
// _c323
// _c324
// _c325
// _c326
// _c327
// _c328
// _c329
// _c330
// _c331
// _c332
// _c333
// _c334
// _c335
// _c336
// _c337
// _c338
// _c339
// _c340
// _c341
// _c342
// _c343
// _c344
// _c345
// _c346
// _c347
// _c348
// _c349
// _c350
// _c351
// _c352
// _c353
// _c354
// _c355
// _c356
// _c357
// _c358
// _c359
// _c360
// _c361
// _c362
// _c363
// _c364
// _c365
// _c366
// _c367
// _c368
// _c369
// _c370
// _c371
// _c372
// _c373
// _c374
// _c375
// _c376
// _c377
// _c378
// _c379
// _c380
// _c381
// _c382
// _c383
// _c384
// _c385
// _c386
// _c387
// _c388
// _c389
// _c390
// _c391
// _c392
// _c393
// _c394
// _c395
// _c396
// _c397
// _c398
// _c399
// _c400
// _c401
// _c402
// _c403
// _c404
// _c405
// _c406
// _c407
// _c408
// _c409
// _c410
// _c411
// _c412
// _c413
// _c414
// _c415
// _c416
// _c417
// _c418
// _c419
// _c420
// _c421
// _c422
// _c423
// _c424
// _c425
// _c426
// _c427
// _c428
// _c429
// _c430
// _c431
// _c432
// _c433
// _c434
// _c435
// _c436
// _c437
// _c438
// _c439
// _c440
// _c441
// _c442
// _c443
// _c444
// _c445
// _c446
// _c447
// _c448
// _c449
// _c450
// _c451
// _c452
// _c453
// _c454
// _c455
// _c456
// _c457
// _c458
// _c459
// _c460
// _c461
// _c462
// _c463
// _c464
// _c465
// _c466
// _c467
// _c468
// _c469
// _c470
// _c471
// _c472
// _c473
// _c474
// _c475
// _c476
// _c477
// _c478
// _c479
// _c480
// _c481
// _c482
// _c483
// _c484
// _c485
// _c486
// _c487
// _c488
// _c489
// _c490
// _c491
// _c492
// _c493
// _c494
// _c495
// _c496
// _c497
// _c498
// _c499
// _c500
// _c501
// _c502
// _c503
// _c504
// _c505
// _c506
// _c507
// _c508
// _c509
// _c510
// _c511
// _c512
// _c513
// _c514
// _c515
// _c516
// _c517
// _c518
// _c519
// _c520
// _c521
// _c522
// _c523
// _c524
// _c525
// _c526
// _c527
// _c528
// _c529
// _c530
// _c531
// _c532
// _c533
// _c534
// _c535
// _c536
// _c537
// _c538
// _c539
// _c540
// _c541
// _c542
// _c543
// _c544
// _c545
// _c546
// _c547
// _c548
// _c549
// _c550
// _c551
// _c552
// _c553
// _c554
// _c555
// _c556
// _c557
// _c558
// _c559
// _c560
// _c561
// _c562
// _c563
// _c564
// _c565
// _c566
// _c567
// _c568
// _c569
// _c570
// _c571
// _c572
// _c573
// _c574
// _c575
// timeId
// patId
// _c16
// _c17
// _c18
// _c19
// _c20
// _c21
// _c22
// _c23
// _c24
// _c25
// _c26
// _c27
// _c28
// _c29
// Wed May 31 21:48:10 CDT 2017

// %% [markdown]
// Adding a schema didn't work for nan/inf values
